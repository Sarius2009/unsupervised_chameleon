# %% [markdown]
# # Segmentation methodology for Chameleon

# %%
# This code has been tested on Python 3.11.7
! pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib~=3.8.3 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 1)) (3.8.3)
# Requirement already satisfied: numpy~=1.26.4 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas~=2.2.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: scipy~=1.12.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 4)) (1.12.0)
# Requirement already satisfied: tqdm~=4.66.2 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 5)) (4.66.2)
# Requirement already satisfied: scikit-learn~=1.4.1.post1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 6)) (1.4.1.post1)
# Requirement already satisfied: ipywidgets~=8.1.2 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 7)) (8.1.2)
# Requirement already satisfied: neptune~=1.10.4 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 8)) (1.10.4)
# Requirement already satisfied: npy_append_array~=0.9.16 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 9)) (0.9.16)
# Requirement already satisfied: omegaconf~=2.3.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: pytorch_lightning~=2.2.5 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 11)) (2.2.5)
# Requirement already satisfied: torch~=2.3 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 12)) (2.9.0+cu130)
# Requirement already satisfied: torchmetrics~=1.4.0.post0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 13)) (1.4.0.post0)
# Requirement already satisfied: picosdk in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 14)) (1.1)
# Requirement already satisfied: h5py in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from -r requirements.txt (line 15)) (3.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from matplotlib~=3.8.3->-r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from matplotlib~=3.8.3->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from matplotlib~=3.8.3->-r requirements.txt (line 1)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from matplotlib~=3.8.3->-r requirements.txt (line 1)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from matplotlib~=3.8.3->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pillow>=8 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from matplotlib~=3.8.3->-r requirements.txt (line 1)) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from matplotlib~=3.8.3->-r requirements.txt (line 1)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from matplotlib~=3.8.3->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from pandas~=2.2.1->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from pandas~=2.2.1->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: colorama in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from tqdm~=4.66.2->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from scikit-learn~=1.4.1.post1->-r requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from scikit-learn~=1.4.1.post1->-r requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: comm>=0.1.3 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipywidgets~=8.1.2->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipywidgets~=8.1.2->-r requirements.txt (line 7)) (9.7.0)
# Requirement already satisfied: traitlets>=4.3.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipywidgets~=8.1.2->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipywidgets~=8.1.2->-r requirements.txt (line 7)) (4.0.15)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipywidgets~=8.1.2->-r requirements.txt (line 7)) (3.0.16)
# Requirement already satisfied: GitPython>=2.0.8 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (3.1.45)
# Requirement already satisfied: PyJWT in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (2.10.1)
# Requirement already satisfied: boto3>=1.28.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (1.40.66)
# Requirement already satisfied: bravado<12.0.0,>=11.0.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (11.1.0)
# Requirement already satisfied: click>=7.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (8.3.0)
# Requirement already satisfied: future>=0.17.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: oauthlib>=2.1.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (3.3.1)
# Requirement already satisfied: psutil in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (7.1.3)
# Requirement already satisfied: requests>=2.20.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (2.32.5)
# Requirement already satisfied: requests-oauthlib>=1.0.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: setuptools in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (1.17.0)
# Requirement already satisfied: swagger-spec-validator>=2.7.4 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (3.0.4)
# Requirement already satisfied: typing-extensions>=3.10.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: urllib3 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.35.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from neptune~=1.10.4->-r requirements.txt (line 8)) (1.9.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from omegaconf~=2.3.0->-r requirements.txt (line 10)) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from omegaconf~=2.3.0->-r requirements.txt (line 10)) (6.0.3)
# Requirement already satisfied: fsspec>=2022.5.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (2025.10.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (0.15.2)
# Requirement already satisfied: filelock in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from torch~=2.3->-r requirements.txt (line 12)) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from torch~=2.3->-r requirements.txt (line 12)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from torch~=2.3->-r requirements.txt (line 12)) (3.5)
# Requirement already satisfied: jinja2 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from torch~=2.3->-r requirements.txt (line 12)) (3.1.6)
# Requirement already satisfied: botocore<1.41.0,>=1.40.66 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from boto3>=1.28.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.40.66)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from boto3>=1.28.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from boto3>=1.28.0->neptune~=1.10.4->-r requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: bravado-core>=5.16.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (6.1.1)
# Requirement already satisfied: monotonic in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.6)
# Requirement already satisfied: msgpack in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.1.2)
# Requirement already satisfied: simplejson in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (3.20.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (3.13.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from GitPython>=2.0.8->neptune~=1.10.4->-r requirements.txt (line 8)) (4.0.12)
# Requirement already satisfied: decorator>=4.3.2 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from requests>=2.20.0->neptune~=1.10.4->-r requirements.txt (line 8)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from requests>=2.20.0->neptune~=1.10.4->-r requirements.txt (line 8)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from requests>=2.20.0->neptune~=1.10.4->-r requirements.txt (line 8)) (2025.10.5)
# Requirement already satisfied: jsonschema in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from swagger-spec-validator>=2.7.4->neptune~=1.10.4->-r requirements.txt (line 8)) (4.25.1)
# Requirement already satisfied: importlib-resources>=1.3 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from swagger-spec-validator>=2.7.4->neptune~=1.10.4->-r requirements.txt (line 8)) (6.5.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from sympy>=1.13.3->torch~=2.3->-r requirements.txt (line 12)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jinja2->torch~=2.3->-r requirements.txt (line 12)) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning~=2.2.5->-r requirements.txt (line 11)) (1.22.0)
# Requirement already satisfied: jsonref in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from gitdb<5,>=4.0.1->GitPython>=2.0.8->neptune~=1.10.4->-r requirements.txt (line 8)) (5.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (0.8.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune~=1.10.4->-r requirements.txt (line 8)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune~=1.10.4->-r requirements.txt (line 8)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema->swagger-spec-validator>=2.7.4->neptune~=1.10.4->-r requirements.txt (line 8)) (0.28.0)
# Requirement already satisfied: wcwidth in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pure-eval in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets~=8.1.2->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: fqdn in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.5.1)
# Requirement already satisfied: isoduration in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: rfc3339-validator in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>0.1.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (0.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.1.0)
# Requirement already satisfied: uri-template in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in d:\neu aufsetzen\studium\11. semester\advsecres\.venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=2.5.1->bravado-core>=5.16.1->bravado<12.0.0,>=11.0.0->neptune~=1.10.4->-r requirements.txt (line 8)) (1.4.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from tqdm.auto import tqdm

from CNN.train import train 
from inference_pipeline.sliding_window_classification import getModule, classifyTrace, saveClassification
from inference_pipeline.segmentation import *
from CNN.build_dataset_chameleon import createSubsets
from inference_pipeline.debug import *
from matplotlib import pyplot as plt
from inference_pipeline.heuristic import removeFalseNegatives, removeFalsePositives, removeFalsePositives_basic

# %% [markdown]
# ## CNN dataset creation

# %%
chameleon_path = "datasets/" + "BASE" + "/" # Patterns: BASE DFS RD MRP CHF
dataset_out_path = "temporary_files"

# %%
createSubsets(chameleon_path, dataset_out_path, reuse_existing_dataset=True)

# %% [markdown]
# ## CNN training

# %% [markdown]
# Each CNN is configure thanks to a YALM configuration file.
# You can set different module hyper-parameters as well as the dataset, the logger, and the experiment configurations.
# Default configuration are in `CNN/configs` directory, both for Neputune logger and for the experiment.
#
# > Some mandatory YALM parameters must be set for each experiment.
# > - Set `log_dir` in the `experiment.yaml` files.
# > - Set `dataset_dir` in the `data.yaml` files to the output folder used by `createSubsets()`.
#
# > Neptune logging and Neptune.ai account are optional and can be enabled or disabled as desired.

# %%
config_folder = "CNN/configs/chameleon_base/" # /path/to/experiment/config/folder/
train(config_folder)

# %% [markdown]
# ## Sliding Window Classification
#
# It is best to restart the jupyter server here, as the traing data might use up memory required for the inference

# %%
import numpy as np
from tqdm.auto import tqdm

from inference_pipeline.sliding_window_classification import getModule, classifyTrace, saveClassification
from inference_pipeline.segmentation import *
from inference_pipeline.debug import *
from matplotlib import pyplot as plt
from inference_pipeline.heuristic import removeFalseNegatives, removeFalsePositives, removeFalsePositives_basic
# Out:
# D:\Neu Aufsetzen\Studium\11. Semester\AdvSecRes\.venv\Lib\site-packages\lightning_fabric\__init__.py:41: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.

# %%
SID = "UN-3"
chameleon_file = "datasets/BASE/chameleon_base_chunk_2.h5"
output_file = "temporary_files/output_file.npy"

module = getModule(SID)
# Out:
# [neptune] [info   ] Neptune initialized. Open in the app: https://app.neptune.ai/la20fo09/Unsupervised-chameleon/
# Experiment config directory: D:\Neu Aufsetzen\Studium\11. Semester\AdvSecRes\temporary_files\ResNet_v1_2025-11-06_19-30-59\configs\chameleon_base

# %% [markdown]
# Compute and save segmentation as file `output_file`.
# Function _classifyTrace_ has a few parameters to configure based on the experiment:
#
# - `stride`: Define the stride to use for the sliding window.
# - `window_size`: Define the size of the sliding window itself.

# %%
window_size = 20_000
stride = 10_000

# %%
classifications = classifyTrace(chameleon_file, module, stride, window_size, batch_size=256)
saveClassification(classifications, output_file)
# Out:
# 0it [00:00, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]
#   0%|          | 0/53 [00:00<?, ?it/s]

# %% [markdown]
# ## Screening

# %% [markdown]
# Compute the segmenation and find the starting sample of each cryptographic operation.

# %%
classification_file = output_file

labels = loaderGt(chameleon_file)
classifications = np.load(classification_file, mmap_mode='r')

gts_starts = []
gts_ends = []
for label in labels:
    gts_starts.append(label['start'])
    gts_ends.append(label['end'])

init_min_distance = 150_000

# %%
major_filter_size = 150
CPs = []

for classification, gt, gt_e in tqdm(zip(classifications, gts_starts, gts_ends), total=len(classifications)):
    CPs.append(segment(classification, major_filter_size, stride, init_min_distance))

# %% [markdown]
# Remove false positive and false negatives from the identified COs

# %%
starts = []
ends = []

for idx in tqdm(range(len(CPs))):
    s, e = removeFalsePositives_basic(CPs[idx]['starts'], CPs[idx]['ends'])
    s, e = removeFalseNegatives(s, e, classifications[idx])
    starts.append(s)
    ends.append(e)

# %%
fnrs_s, fprs_s = [],[]
fnrs_e, fprs_e = [],[]

for idx in tqdm(range(len(CPs))):
    fpr, fnr = errorRate(gts_starts[idx], np.asarray(starts[idx]), stride)
    fprs_s.append(fpr)
    fnrs_s.append(fnr)
    fpr, fnr = errorRate(gts_ends[idx], np.asarray(ends[idx]), stride)
    fprs_e.append(fpr)
    fnrs_e.append(fnr)
    
print(f"Total start mean FPR: {round(np.mean(fprs_s)*100,2)}%")
print(f"Total start mean FNR: {round(np.mean(fnrs_s)*100,2)}%")
print(f"Total end mean FPR: {round(np.mean(fprs_e)*100,2)}%")
print(f"Total end mean FNR: {round(np.mean(fnrs_e)*100,2)}%")

# %% [markdown]
# ## Visualization
#
# Visualize the detected COs and ground truth (GT) for a given trace.
#
# **First Subplot**: Draws black vertical lines for detected COs' _starts_ and red dashed vertical lines for GT.
# **Second Subplot**: Draws grey vertical lines for detected COs' _ends_ and yellow dashed vertical lines for GT.
# **Third Subplot**: Plots classification for each point in the trace.

# %%
n_trace = 0
center = 100_000
margin = 20_000
lim = (center-margin, center+margin)

fig, ax = plt.subplots(3, figsize=(13, 7))
plt.rcParams.update({'font.size': 18})
fig.tight_layout(pad=2.0)

ax[0].set_xlim(lim)
for sample in starts[n_trace][1:]:
    ax[0].axvline(x=sample, color='black', linestyle='-')
ax[0].axvline(x=starts[n_trace][0], color='black', linestyle='-', label="Found CO's start")

for sample in gts_starts[n_trace][1:]:
    ax[0].axvline(x=sample//stride, color='r', linestyle='--')
ax[0].axvline(x=gts_starts[n_trace][0]//stride, color='r', linestyle='--', label='Start GT')
ax[0].legend(loc='lower right', bbox_to_anchor=(1, 0.95))


ax[1].set_xlim(lim)
for sample in ends[n_trace][1:]:
    ax[1].axvline(x=sample, color='grey', linestyle='-')
ax[1].axvline(x=ends[n_trace][0], color='grey', linestyle='-', label="Found CO's end")

for sample in gts_ends[n_trace][1:]:
    ax[1].axvline(x=sample//stride, color='y', linestyle='--')
ax[1].axvline(x=gts_ends[n_trace][0]//stride, color='y', linestyle='--', label='End GT')
ax[1].legend(loc='lower right', bbox_to_anchor=(1, 0.95))


ax[2].set_xlim(lim)
ax[2].plot(np.argmax(classifications[n_trace], axis=1))
